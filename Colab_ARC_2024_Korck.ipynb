# %% [markdown]
# <a href="https://colab.research.google.com/github/Korck-lab/labs/blob/production/Colab_ARC_2024_Korck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'arc-prize-2024:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-competitions-data%2Fkaggle-v2%2F67357%2F8876241%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240618%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240618T210919Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading arc-prize-2024, 321600 bytes compressed
# [==================================================] 321600 bytes downloaded
# Downloaded and uncompressed: arc-prize-2024
# Data source import complete.

# %% [markdown]
# <center>
# <img src="https://i.postimg.cc/26RtyM0s/3221asdf.jpg" width=1100>
# </center>

# %% [markdown]
# # <div  style="color:white; border:lightgreen solid;  font-weight:bold; font-size:120%; text-align:center;padding:12.0px; background:black">1. OVERVIEW</div>

# %% [markdown]
# # Goal
# The objective of this competition is to create an algorithm that is capable of solving abstract reasoning tasks. Critically, these are novel tasks: tasks that the algorithm has never seen before. Hence, **simply memorizing** a set of reasoning templates will **not suffice**.
#
# The goal is to construct the output grid(s) corresponding to the test input grid(s), using 2 trials for each test input.

# %% [markdown]
# # Data overview

# %% [markdown]
# "Constructing the output grid" involves picking the height and width of the output grid, then filling each cell in the grid with a symbol (integer between 0 and 9, which are visualized as **colors**). **Only exact solutions** (all cells match the expected answer) can be said to be correct.

# %% [markdown]
# # <div  style="color:white; border:lightgreen solid;  font-weight:bold; font-size:120%; text-align:center;padding:12.0px; background:black">2. DATA LOADING AND PREPARATION</div>

# %% [markdown]
# ## Import libraries and define parameters

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from   matplotlib import colors
import seaborn as sns

import json
import os
from pathlib import Path

from subprocess import Popen, PIPE, STDOUT
from glob import glob

# %%
base_path='/kaggle/input/arc-prize-2024/'
# Loading JSON data
def load_json(file_path):
    with open(file_path) as f:
        data = json.load(f)
    return data

# %%
# Reading files
training_challenges =  load_json(base_path +'arc-agi_training_challenges.json')
training_solutions =   load_json(base_path +'arc-agi_training_solutions.json')
evaluation_challenges =load_json(base_path +'arc-agi_evaluation_challenges.json')
evaluation_solutions = load_json(base_path +'arc-agi_evaluation_solutions.json')

# %% [markdown]
# # <div  style="color:white; border:lightgreen solid;  font-weight:bold; font-size:120%; text-align:center;padding:12.0px; background:black">3. DATA EXPLORATION</div>

# %% [markdown]
# All datasets have 400 JSON tasks:

# %%
print(f'Number of training challenges = {len(training_challenges)}')
# Out:
# Number of training challenges = 400

# %%
print(f'Number of training solutions = {len(training_solutions)}')
# Out:
# Number of training solutions = 400

# %%
print(f'Number of evaluation challenges = {len(evaluation_challenges)}')
# Out:
# Number of evaluation challenges = 400

# %%
print(f'Number of evaluation solutions = {len(evaluation_solutions)}')
# Out:
# Number of evaluation solutions = 400

# %% [markdown]
# The names of the first fife ""training challenges" are shown below:

# %%
for i in range(5):
    t=list(training_challenges)[i]
    task=training_challenges[t]
    print(f'Set #{i}, {t}')
# Out:
# Set #0, 007bbfb7
# Set #1, 00d62c1b
# Set #2, 017c7c7b
# Set #3, 025d127b
# Set #4, 045e512c

# %% [markdown]
# In each task, there are **two** dictionary keys, **train** and **test**. We learn the pattern from the train input-output pairs, and then apply the pattern to the test input, to predict an output.

# %%
task = training_challenges['007bbfb7']
print(task.keys())
# Out:
# dict_keys(['test', 'train'])

# %% [markdown]
# Tasks have multiple train input-output pairs. Most tasks have a single test input-output pair, although some have more than one.

# %%
n_train_pairs = len(task['train'])
n_test_pairs = len(task['test'])

print(f'task contains {n_train_pairs} training pairs')
print(f'task contains {n_test_pairs} test pairs')
# Out:
# task contains 5 training pairs
# task contains 1 test pairs

# %% [markdown]
# Dive into the first train input-output pair, we can see the grids are expressed as 2d lists with integers 0-9:

# %%
display(task['train'][0]['input'])
display(task['train'][0]['output'])
# Out:
# [[0, 7, 7], [7, 7, 7], [0, 7, 7]]
# [[0, 0, 0, 0, 7, 7, 0, 7, 7],
#  [0, 0, 0, 7, 7, 7, 7, 7, 7],
#  [0, 0, 0, 0, 7, 7, 0, 7, 7],
#  [0, 7, 7, 0, 7, 7, 0, 7, 7],
#  [7, 7, 7, 7, 7, 7, 7, 7, 7],
#  [0, 7, 7, 0, 7, 7, 0, 7, 7],
#  [0, 0, 0, 0, 7, 7, 0, 7, 7],
#  [0, 0, 0, 7, 7, 7, 7, 7, 7],
#  [0, 0, 0, 0, 7, 7, 0, 7, 7]]

# %% [markdown]
# ### Function to plot input/output pairs of a task

# %%
# 0:black, 1:blue, 2:red, 3:greed, 4:yellow, # 5:gray, 6:magenta, 7:orange, 8:sky, 9:brown

_cmap = colors.ListedColormap(
    ['#000000', '#0074D9','#FF4136','#2ECC40','#FFDC00',
     '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
norm = colors.Normalize(vmin=0, vmax=9)

plt.figure(figsize=(4, 1), dpi=200)
plt.imshow([list(range(10))], cmap=_cmap, norm=norm)
plt.xticks(list(range(10)))
plt.yticks([])
plt.show()

# %%
def plot_one(ax, i,train_or_test,input_or_output):
    cmap = colors.ListedColormap(
        ['#000000', '#0074D9','#FF4136','#2ECC40','#FFDC00',
         '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
    norm = colors.Normalize(vmin=0, vmax=9)

    input_matrix = task[train_or_test][i][input_or_output]
    ax.imshow(input_matrix, cmap=cmap, norm=norm)
    ax.grid(True,which='both',color='lightgrey', linewidth=0.5)

    ax.set_yticks([x-0.5 for x in range(1+len(input_matrix))])
    ax.set_xticks([x-0.5 for x in range(1+len(input_matrix[0]))])
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.set_title(train_or_test + ' '+input_or_output)


def plot_task(task):
    """
    Plots the first train and test pairs of a specified task,
    using same color scheme as the ARC app
    """
    num_train = len(task['train'])
    fig, axs = plt.subplots(2, num_train, figsize=(3*num_train,3*2))
    for i in range(num_train):
        plot_one(axs[0,i],i,'train','input')
        plot_one(axs[1,i],i,'train','output')
    plt.tight_layout()
    plt.show()

#     num_test = len(task['test'])
#     fig, axs = plt.subplots(2, num_test, figsize=(3*num_test,3*2))
#     if num_test==1:
#         plot_one(axs[0],0,'test','input')
#         plot_one(axs[1],0,'test','output')
#     else:
#         for i in range(num_test):
#             plot_one(axs[0,i],i,'test','input')
#             plot_one(axs[1,i],i,'test','output')
#     plt.tight_layout()
#     plt.show()

# %% [markdown]
# # Visualization Training set

# %%
for i in range(5):
    t=list(training_challenges)[i]
    task=training_challenges[t]
    print(f'Set #{i}, {t}')
    plot_task(task)
# Out:
# Set #0, 007bbfb7
# Set #1, 00d62c1b
# Set #2, 017c7c7b
# Set #3, 025d127b
# Set #4, 045e512c

# %% [markdown]
# # Visualization Evaluating set

# %%
for i in range(5):
    t=list(evaluation_challenges)[i]
    task=evaluation_challenges[t]
    print(f'Set #{i}, {t}')
    plot_task(task)
# Out:
# Set #0, 00576224
# Set #1, 009d5c81
# Set #2, 00dbd492
# Set #3, 03560426
# Set #4, 05a7bcf2

# %% [markdown]
# # <div  style="color:white; border:lightgreen solid;  font-weight:bold; font-size:120%; text-align:center;padding:12.0px; background:black">4. MODELLING</div>

# %%
import numpy as np
from matplotlib import colors
import matplotlib.pyplot as plt
from typing import Literal

def create_rgb_array(input_output_matrix):
#     print("Matrix:")
#     print(input_output_matrix)

    cmap = colors.ListedColormap(
        ['#000000', '#0074D9','#FF4136','#2ECC40','#FFDC00',
         '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
    norm = colors.Normalize(vmin=0, vmax=9)

    normed_matrix = norm(input_output_matrix)
    rgb_array = cmap(normed_matrix)
    rgb_array = rgb_array[..., :3]

#     print("RGB Array (Normalized):")
#     print(rgb_array)

    return rgb_array

def get_rgb_task(task, kind:Literal['train', 'test']='train'):
    num_train = len(task[kind])
    train_input_rgb = []
    train_output_rgb = []

    for i in range(num_train):
        input_matrix = task[kind][i]['input']
        output_matrix = task[kind][i]['output']

        train_input_rgb.append(create_rgb_array(input_matrix))
        train_output_rgb.append(create_rgb_array(output_matrix))

    return train_input_rgb, train_output_rgb

def display_with_matplotlib(rgb_array):
    plt.imshow(rgb_array)
    plt.axis('off')
    plt.show()

t = list(training_challenges)[0]
task = training_challenges[t]
print(f'Set #{0}, {t}')
# plot_task(task)
train_input_rgb, train_output_rgb = get_rgb_task(task, 'train')
display_with_matplotlib(train_input_rgb[0])
# Out:
# Set #0, 007bbfb7

# %%
import numpy as np
import torch
import torch.nn as nn
import bisect
from typing import List, Tuple, Literal
import matplotlib.pyplot as plt
import torch.optim as optim
from PIL import Image
import matplotlib.colors as colors
import pickle

# %%
import json
import pickle
import numpy as np
import matplotlib.colors as colors
from typing import Literal

# Constants for maximum grid dimensions
MAX_ROWS, MAX_COLS = 30, 30

# Pad the array to the given dimensions
def pad_array(array, max_rows=MAX_ROWS, max_cols=MAX_COLS, padding_value=-1.0):
    padded_array = np.full((max_rows, max_cols), padding_value)
    rows, cols = len(array), len(array[0])
    start_row = (max_rows - rows) // 2
    start_col = (max_cols - cols) // 2
    padded_array[start_row:start_row+rows, start_col:start_col+cols] = array
    return padded_array

# Convert the padded array to RGB
def create_rgb_array(input_matrix):
    cmap = colors.ListedColormap(
        ['#000000', '#0074D9','#FF4136','#2ECC40','#FFDC00',
         '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
    norm = colors.Normalize(vmin=0, vmax=9)
    normed_matrix = norm(input_matrix)
    rgb_array = cmap(normed_matrix)
    rgb_array = rgb_array[..., :3]
    return rgb_array

# Get padded RGB arrays for the task
def get_padded_rgb_task(task, kind: Literal['train', 'test'] = 'train'):
    input_rgb, output_rgb = [], []
    for pair in task[kind]:
        input_matrix = pad_array(pair['input'])
        input_rgb.append(create_rgb_array(input_matrix))
        if 'output' in pair:
            output_matrix = pad_array(pair['output'])
            output_rgb.append(create_rgb_array(output_matrix))
        else:
            output_rgb.append(None)
    return input_rgb, output_rgb

# %%
# Process and save the dataset with size information
def save_dataset_with_sizes(training_challenges, filename):
    dataset = {
        'train_input_rgb': [],
        'train_output_rgb': [],
        'test_input_rgb': [],
        'train_input_sizes': [],
        'train_output_sizes': [],
        'test_input_sizes': [],
        'labels': []
    }

    for i in range(len(training_challenges)):
        t = list(training_challenges)[i]
        task = training_challenges[t]
        print(f'Processing Set #{i}, {t}', end='\r')

        # Process training pairs
        train_input_rgb, train_output_rgb = get_padded_rgb_task(task, 'train')
        for j in range(len(task['train'])):
            input_matrix = task['train'][j]['input']
            output_matrix = task['train'][j]['output']
            dataset['train_input_rgb'].append(train_input_rgb[j])
            dataset['train_output_rgb'].append(train_output_rgb[j])
            dataset['train_input_sizes'].append((len(input_matrix), len(input_matrix[0])))
            dataset['train_output_sizes'].append((len(output_matrix), len(output_matrix[0])))
            dataset['labels'].append(t)

        # Process test pairs (only inputs)
        test_input_rgb, _ = get_padded_rgb_task(task, 'test')
        for k in range(len(task['test'])):
            input_matrix = task['test'][k]['input']
            dataset['test_input_rgb'].append(test_input_rgb[k])
            dataset['test_input_sizes'].append((len(input_matrix), len(input_matrix[0])))

    # Debug: Verify dataset content
    print(f"\nTotal valid train samples: {len(dataset['train_input_rgb'])}")
    print(f"Total valid test samples: {len(dataset['test_input_rgb'])}")

    # Save the dataset to a file using pickle
    with open(filename, 'wb') as f:
        pickle.dump(dataset, f)

    print(f'\nDataset saved to {filename}')

# Example usage
save_dataset_with_sizes(training_challenges, 'processed_dataset_with_sizes.pkl')
# Out:
# Processing Set #399, ff805c23
# Total valid train samples: 1302
# Total valid test samples: 416
#
# Dataset saved to processed_dataset_with_sizes.pkl

# %%
import torch
import numpy as np
import pickle

# Function to flatten RGB arrays with size information
def flatten_rgb_arrays_with_sizes(rgb_arrays, sizes):
    flattened_arrays = []
    for rgb_array, size in zip(rgb_arrays, sizes):
        flattened_array = rgb_array.flatten()
        flattened_arrays.append(np.concatenate((flattened_array, np.array(size))))
    return np.array(flattened_arrays)

# Function to reshape predictions back to 2D
def reshape_predictions(predictions, sizes):
    reshaped_predictions = []
    num_features = predictions.shape[1] - 2  # excluding size information
    for i, size in enumerate(sizes):
        height, width = size
        reshaped_prediction = predictions[i][:num_features].reshape(height, width, 3)
        reshaped_predictions.append(reshaped_prediction)
    return reshaped_predictions

# Function to calculate accuracy
def calculate_accuracy(predictions, ground_truth):
    correct = 0
    for pred, gt in zip(predictions, ground_truth):
        if np.array_equal(pred, gt):
            correct += 1
    accuracy = correct / len(ground_truth)
    return accuracy

# Load the dataset with size information
def load_dataset_with_sizes(filename):
    with open(filename, 'rb') as f:
        dataset = pickle.load(f)
    return dataset

# Example usage
dataset = load_dataset_with_sizes('processed_dataset_with_sizes.pkl')
train_input_rgb = dataset['train_input_rgb']
train_output_rgb = dataset['train_output_rgb']
test_input_rgb = dataset['test_input_rgb']
train_input_sizes = dataset['train_input_sizes']
train_output_sizes = dataset['train_output_sizes']
test_input_sizes = dataset['test_input_sizes']
labels = dataset['labels']

# # Flatten the train data for validation
# train_input_rgb_flat = flatten_rgb_arrays_with_sizes(train_input_rgb, train_input_sizes)
# train_output_rgb_flat = flatten_rgb_arrays_with_sizes(train_output_rgb, train_output_sizes)

# X_train = torch.FloatTensor(train_input_rgb_flat)
# y_train = torch.FloatTensor(train_output_rgb_flat)

# # Debug: Print shapes
# print(f"X_train shape: {X_train.shape}")
# print(f"y_train shape: {y_train.shape}")

# # Make predictions with the trained model for validation
# with torch.no_grad():
#     outputs = trained_model(X_train)

# # Debug: Print shapes after prediction
# print(f"Outputs shape after prediction: {outputs.shape}")

# # Reshape the predictions
# reshaped_predictions = reshape_predictions(outputs.numpy(), train_output_sizes)
# reshaped_ground_truth = reshape_predictions(y_train.numpy(), train_output_sizes)

# # Debug: Print lengths after reshaping
# print(f"Reshaped predictions length: {len(reshaped_predictions)}")
# print(f"Reshaped ground truth length: {len(reshaped_ground_truth)}")

# # Calculate accuracy
# accuracy = calculate_accuracy(reshaped_predictions, reshaped_ground_truth)
# print(f'Accuracy: {accuracy:.4f}')

# %%
# import pickle

# # Load the dataset with size information
# def load_dataset_with_sizes(filename):
#     with open(filename, 'rb') as f:
#         dataset = pickle.load(f)
#     return dataset

# # Example usage
# dataset = load_dataset_with_sizes('processed_dataset_with_sizes.pkl')
# train_input_rgb = dataset['train_input_rgb']
# train_output_rgb = dataset['train_output_rgb']
# test_input_rgb = dataset['test_input_rgb']
# train_input_sizes = dataset['train_input_sizes']
# train_output_sizes = dataset['train_output_sizes']
# test_input_sizes = dataset['test_input_sizes']
# labels = dataset['labels']

# Display the first example of train set
display_with_matplotlib(train_input_rgb[0])

# If you want to display the first example of the test set (if it exists)
if test_input_rgb and test_input_rgb[0] is not None:
    display_with_matplotlib(test_input_rgb[0])

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ExponentialLR
import numpy as np
import os

class SplineActivation(nn.Module):
    def __init__(self, num_knots=10, degree=3):
        super(SplineActivation, self).__init__()
        self.num_knots = num_knots
        self.degree = degree
        self.x = nn.Parameter(torch.linspace(-1.0, 1.0, num_knots), requires_grad=False)

        # Allow y to be updated during training
        self.y = nn.Parameter(torch.sin(self.x * 3.14159) + 0.1 * torch.randn(self.num_knots), requires_grad=True)

        # Initial computation of coefficients, just for initial debugging
        _, self.coefficients = self.compute_spline(self.x, self.y)

        self.w = nn.Parameter(torch.tensor(1.0))  # Initialize weight
        self.basis_function = nn.SiLU()  # Using SiLU (Swish) as basis function

    def compute_spline(self, x, y):
        if x.size(0) < 3:
            raise ValueError('Too short an array')
        if x.size(0) != y.size(0):
            raise ValueError('Array lengths are different')

        h = x[1:] - x[:-1]
        if torch.any(h <= 0):
            raise ValueError('X must be strictly increasing')

        n = x.size(0)
        A, B, C = self.create_tridiagonal_matrix(n, h)
        D = self.create_target(n, h, y)
        M = self.solve_tridiagonal_system(A, B, C, D)

        coefficients = torch.stack([
            (M[1:] - M[:-1]) * h**2 / 6,
            M[:-1] * h**2 / 2,
            (y[1:] - y[:-1] - (M[1:] + 2 * M[:-1]) * h**2 / 6),
            y[:-1]
        ], dim=1)

        return self.spline_function(x, coefficients), coefficients

    def create_tridiagonal_matrix(self, n, h):
        A = torch.cat((h[:-1] / (h[:-1] + h[1:]), torch.tensor([0.0], device=h.device)))
        B = torch.full((n,), 2.0, device=h.device)
        C = torch.cat((torch.tensor([0.0], device=h.device), h[1:] / (h[:-1] + h[1:])))
        return A, B, C

    def create_target(self, n, h, y):
        diff_quotients = 6 * ((y[2:] - y[1:-1]) / h[1:] - (y[1:-1] - y[:-2]) / h[:-1]) / (h[:-1] + h[1:])
        return torch.cat((torch.tensor([0.0], device=h.device), diff_quotients, torch.tensor([0.0], device=h.device)))

    def solve_tridiagonal_system(self, A, B, C, D):
        n = B.size(0)
        c_p = torch.zeros(n, device=B.device)
        d_p = torch.zeros(n, device=B.device)
        X = torch.zeros(n, device=B.device)

        c_p[0] = C[0] / B[0]
        d_p[0] = D[0] / B[0]
        for i in range(1, n-1):
            denom = B[i] - A[i-1] * c_p[i-1]
            c_p[i] = C[i] / denom
            d_p[i] = (D[i] - A[i-1] * d_p[i-1]) / denom

        X[-1] = d_p[-1]
        for i in range(n-2, -1, -1):
            X[i] = d_p[i] - c_p[i] * X[i+1]

        return X

    def spline_function(self, x, coefficients):
        def spline(val):
            idx = min(bisect.bisect(x.cpu().numpy(), val) - 1, x.size(0) - 2)
            z = (val - x[idx].item()) / (x[idx+1].item() - x[idx].item())
            C = coefficients[idx]
            return (((C[0] * z + C[1]) * z + C[2]) * z + C[3]).item()
        return spline

    def forward(self, x):
        x_clipped = torch.clamp(x, -1, 1)

        _, coefficients = self.compute_spline(self.x, self.y)

        indices = torch.searchsorted(self.x, x_clipped.detach(), right=True) - 1
        indices = torch.clamp(indices, 0, self.num_knots - 2)
        idx_x = self.x[indices]
        idx_x1 = self.x[indices + 1]
        h = idx_x1 - idx_x
        z = (x_clipped - idx_x) / h
        C = coefficients[indices]

        z = z.unsqueeze(-1)
        C = C.unsqueeze(2)
        y_clipped = (((C[..., 0] * z + C[..., 1]) * z + C[..., 2]) * z + C[..., 3])

        return self.w * (self.basis_function(x) + y_clipped.squeeze(-1))

class KAN(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, kernel_type='spline', num_knots=10):
        super(KAN, self).__init__()
        self.phi1 = nn.Linear(input_dim, hidden_dim)
        self.psi1 = nn.Linear(input_dim, hidden_dim)
        self.phi2 = nn.Linear(hidden_dim, hidden_dim)
        self.psi2 = nn.Linear(hidden_dim, hidden_dim)
        self.phi3 = nn.Linear(hidden_dim, output_dim)
        self.psi3 = nn.Linear(hidden_dim, output_dim)
        self._he_init()

        if kernel_type == 'spline':
            self.spline1 = SplineActivation(num_knots)
            self.spline2 = SplineActivation(num_knots)
            self.spline3 = SplineActivation(num_knots)
            self.spline4 = SplineActivation(num_knots)
            self.spline5 = SplineActivation(num_knots)
            self.spline6 = SplineActivation(num_knots)

    # He initialization function
    def _he_init(self):
        for layer in [self.phi1, self.psi1, self.phi2, self.psi2, self.phi3, self.psi3]:
#         for layer in [self.phi1, self.phi2, self.phi3]:
            nn.init.kaiming_normal_(layer.weight)
            if layer.bias is not None:
                nn.init.constant_(layer.bias, 0)

    def forward(self, x):
        def apply_activation(act, x):
            return act(x)

        x1 = apply_activation(self.spline1, self.phi1(x))
        x2 = apply_activation(self.spline2, self.psi1(x))
        sum_x = x1 + x2
        x3 = apply_activation(self.spline3, self.phi2(sum_x))
        x4 = apply_activation(self.spline4, self.psi2(sum_x))
        sum_x2 = x3 + x4
        x5 = apply_activation(self.spline5, self.phi3(sum_x2))
        x6 = apply_activation(self.spline6, self.psi3(sum_x2))
        output = x5 + x6
#         return torch.tanh(output)
        return output

def train_model(model, X_train, y_train, epochs=200, learning_rate=0.01, save_step=10, save_path="model_checkpoints", device='cpu'):
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = ExponentialLR(optimizer, gamma=0.975)

    loss_list = []

    if not os.path.exists(save_path):
        os.makedirs(save_path)

    model.to(device)
    X_train = X_train.to(device)
    y_train = y_train.to(device)

    for epoch in range(epochs):
        model.train()
        optimizer.zero_grad()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()

        loss_list.append(loss.item())
        if (epoch + 1) % save_step == 0:
            scheduler.step()

            torch.save(model.state_dict(), os.path.join(save_path, f"model_epoch_{epoch + 1}.pth"))
            print(f"Epoch [{epoch + 1}/{epochs}], Loss: {loss.item():.4f}, Model saved.")

    print(f"Training complete! Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}")
    return model, loss_list

# %%
# Set global seed for reproducibility
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# Usage for GPU/CPU

# Choose the device based on availability
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Flatten the train data
train_input_rgb_flat = flatten_rgb_arrays_with_sizes(train_input_rgb, train_input_sizes)
train_output_rgb_flat = flatten_rgb_arrays_with_sizes(train_output_rgb, train_output_sizes)

X_train = torch.FloatTensor(train_input_rgb_flat)
y_train = torch.FloatTensor(train_output_rgb_flat)

input_dim = X_train.shape[1]
output_dim = y_train.shape[1]
hidden_dim = (input_dim + output_dim)//2

num_knots = 30
epochs = 2000
learning_rate = 0.01
save_step = 10

# %%
save_path = f"k{num_knots}_id{input_dim}_hd{hidden_dim}_od{output_dim}_model_checkpoints"
print(f'Saving model to {save_path}')
# Out:
# Saving model to k30_id2702_hd2702_od2702_model_checkpoints

# %%
kan_model = KAN(input_dim, hidden_dim, output_dim, kernel_type='spline', num_knots=num_knots)
trained_model, loss_list = train_model(kan_model, X_train, y_train, epochs=epochs, learning_rate=learning_rate, save_step=save_step, save_path=save_path, device=device)
# Out:
# Epoch [10/2000], Loss: 0.6418, Model saved.
# Epoch [20/2000], Loss: 0.1208, Model saved.
# Epoch [30/2000], Loss: 0.1219, Model saved.
# Epoch [40/2000], Loss: 0.1208, Model saved.
# Epoch [50/2000], Loss: 0.1188, Model saved.
# Epoch [60/2000], Loss: 0.1167, Model saved.
# Epoch [70/2000], Loss: 0.1146, Model saved.
# Epoch [80/2000], Loss: 0.1126, Model saved.
# Epoch [90/2000], Loss: 0.1110, Model saved.
# Epoch [100/2000], Loss: 0.1095, Model saved.
# Epoch [110/2000], Loss: 0.1082, Model saved.
# Epoch [120/2000], Loss: 0.1071, Model saved.
# Epoch [130/2000], Loss: 0.1063, Model saved.
# Epoch [140/2000], Loss: 0.1055, Model saved.
# Epoch [150/2000], Loss: 0.1049, Model saved.
# Epoch [160/2000], Loss: 0.1044, Model saved.
# Epoch [170/2000], Loss: 0.1040, Model saved.
# Epoch [180/2000], Loss: 0.1036, Model saved.
# Epoch [190/2000], Loss: 0.1033, Model saved.
# Epoch [200/2000], Loss: 0.1031, Model saved.
# Epoch [210/2000], Loss: 0.1029, Model saved.
# Epoch [220/2000], Loss: 0.1028, Model saved.
# Epoch [230/2000], Loss: 0.1027, Model saved.
# Epoch [240/2000], Loss: 0.1026, Model saved.
# Epoch [250/2000], Loss: 0.1025, Model saved.
# Epoch [260/2000], Loss: 0.1024, Model saved.
# Epoch [270/2000], Loss: 0.1024, Model saved.
# Epoch [280/2000], Loss: 0.1023, Model saved.
# Epoch [290/2000], Loss: 0.1023, Model saved.
# Epoch [300/2000], Loss: 0.1023, Model saved.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 kan_model = KAN(input_dim, hidden_dim, output_dim, kernel_type='spline', num_knots=num_knots)
# ----> 2 trained_model, loss_list = train_model(kan_model, X_train, y_train, epochs=epochs, learning_rate=learning_rate, save_step=save_step, save_path=save_path, device=device)
#
# Cell In[22], line 166, in train_model(model, X_train, y_train, epochs, learning_rate, save_step, save_path, device)
#     164 outputs = model(X_train)
#     165 loss = criterion(outputs, y_train)
# --> 166 loss.backward()
#     167 optimizer.step()
#     169 loss_list.append(loss.item())
#
# File /opt/conda/lib/python3.10/site-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File /opt/conda/lib/python3.10/site-packages/torch/autograd/__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
import torch
import numpy as np

# Function to reshape predictions back to 2D
def reshape_predictions(predictions, sizes):
    reshaped_predictions = []
    num_features = predictions.shape[1] - 2  # excluding size information
    for i, size in enumerate(sizes):
        height, width = size
        reshaped_prediction = predictions[i][:num_features].reshape(height, width, 3)
        reshaped_predictions.append(reshaped_prediction)
    return reshaped_predictions

# Function to calculate accuracy
def calculate_accuracy(predictions, ground_truth):
    correct = 0
    for pred, gt in zip(predictions, ground_truth):
        if np.array_equal(pred, gt):
            correct += 1
    accuracy = correct / len(ground_truth)
    return accuracy

# Function to load and evaluate the model
def evaluate_model(model, X_test, y_test, test_output_sizes, device='cpu'):
    model.to(device)
    X_test = X_test.to(device)
    y_test = y_test.to(device)

    with torch.no_grad():
        outputs = model(X_test)

    reshaped_predictions = reshape_predictions(outputs.cpu().numpy(), test_output_sizes)
    reshaped_ground_truth = reshape_predictions(y_test.cpu().numpy(), test_output_sizes)

    accuracy = calculate_accuracy(reshaped_predictions, reshaped_ground_truth)
    print(f'Accuracy: {accuracy:.4f}')
    return accuracy

test_input_rgb = dataset['train_input_rgb']
test_output_rgb = dataset['train_output_rgb']
test_input_sizes = dataset['train_input_sizes']
test_output_sizes = dataset['train_output_sizes']

test_input_rgb_flat = flatten_rgb_arrays_with_sizes(test_input_rgb, test_input_sizes)
test_output_rgb_flat = flatten_rgb_arrays_with_sizes(test_output_rgb, test_output_sizes)

X_test = torch.FloatTensor(test_input_rgb_flat)
y_test = torch.FloatTensor(test_output_rgb_flat)

# # Load the trained model
# trained_model = KAN(input_dim, hidden_dim, output_dim, kernel_type='spline', num_knots=num_knots)
# trained_model.load_state_dict(torch.load('model_checkpoints/model_epoch_2000.pth'))

# Evaluate the model
evaluate_model(trained_model, X_test, y_test, test_output_sizes, device=device)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 55
#      48 y_test = torch.FloatTensor(test_output_rgb_flat)
#      50 # # Load the trained model
#      51 # trained_model = KAN(input_dim, hidden_dim, output_dim, kernel_type='spline', num_knots=num_knots)
#      52 # trained_model.load_state_dict(torch.load('model_checkpoints/model_epoch_2000.pth'))
#      53
#      54 # Evaluate the model
# ---> 55 evaluate_model(trained_model, X_test, y_test, test_output_sizes, device=device)
#
# Cell In[27], line 32, in evaluate_model(model, X_test, y_test, test_output_sizes, device)
#      29 with torch.no_grad():
#      30     outputs = model(X_test)
# ---> 32 reshaped_predictions = reshape_predictions(outputs.cpu().numpy(), test_output_sizes)
#      33 reshaped_ground_truth = reshape_predictions(y_test.cpu().numpy(), test_output_sizes)
#      35 accuracy = calculate_accuracy(reshaped_predictions, reshaped_ground_truth)
#
# Cell In[27], line 10, in reshape_predictions(predictions, sizes)
#       8 for i, size in enumerate(sizes):
#       9     height, width = size
# ---> 10     reshaped_prediction = predictions[i][:num_features].reshape(height, width, 3)
#      11     reshaped_predictions.append(reshaped_prediction)
#      12 return reshaped_predictions
#
# ValueError: cannot reshape array of size 2700 into shape (9,9,3)

# %%
import torch
import numpy as np

# Function to flatten RGB arrays with size information
def flatten_rgb_arrays_with_sizes(rgb_arrays, sizes):
    flattened_arrays = []
    for rgb_array, size in zip(rgb_arrays, sizes):
        flattened_array = rgb_array.flatten()
        flattened_arrays.append(np.concatenate((flattened_array, np.array(size))))
    return np.array(flattened_arrays)

# Function to reshape predictions back to 2D
def reshape_predictions(predictions, sizes):
    reshaped_predictions = []
    num_features = predictions.shape[1] - 2  # excluding size information
    for i, size in enumerate(sizes):
        height, width = size
        # Ensure that the number of features matches the expected shape
        expected_size = height * width * 3
        actual_size = predictions[i][:num_features].shape[0]
        if expected_size != actual_size:
            print(f"Shape mismatch: expected {expected_size}, got {actual_size}")
        reshaped_prediction = predictions[i][:num_features].reshape(height, width, 3)
        reshaped_predictions.append(reshaped_prediction)
    return reshaped_predictions

# Function to calculate accuracy
def calculate_accuracy(predictions, ground_truth):
    correct = 0
    for pred, gt in zip(predictions, ground_truth):
        if np.array_equal(pred, gt):
            correct += 1
    accuracy = correct / len(ground_truth)
    return accuracy

# Function to load and evaluate the model
def evaluate_model(model, X_test, y_test, test_output_sizes, device='cpu'):
    model.to(device)
    X_test = X_test.to(device)
    y_test = y_test.to(device)

    with torch.no_grad():
        outputs = model(X_test)

    reshaped_predictions = reshape_predictions(outputs.cpu().numpy(), test_output_sizes)
    reshaped_ground_truth = reshape_predictions(y_test.cpu().numpy(), test_output_sizes)

    accuracy = calculate_accuracy(reshaped_predictions, reshaped_ground_truth)
    print(f'Accuracy: {accuracy:.4f}')

    # Plot the first few predictions and ground truth for comparison
    import matplotlib.pyplot as plt
    for i in range(min(5, len(reshaped_predictions))):
        fig, axs = plt.subplots(1, 2, figsize=(10, 5))
        axs[0].imshow(reshaped_predictions[i])
        axs[0].set_title('Prediction')
        axs[1].imshow(reshaped_ground_truth[i])
        axs[1].set_title('Ground Truth')
        plt.show()

    return accuracy

# Load the dataset and use train set for evaluation
dataset = load_dataset_with_sizes('processed_dataset_with_sizes.pkl')
test_input_rgb = dataset['train_input_rgb']
test_output_rgb = dataset['train_output_rgb']
test_input_sizes = dataset['train_input_sizes']
test_output_sizes = dataset['train_output_sizes']

test_input_rgb_flat = flatten_rgb_arrays_with_sizes(test_input_rgb, test_input_sizes)
test_output_rgb_flat = flatten_rgb_arrays_with_sizes(test_output_rgb, test_output_sizes)

X_test = torch.FloatTensor(test_input_rgb_flat)
y_test = torch.FloatTensor(test_output_rgb_flat)

# # Load the trained model
# trained_model = KAN(input_dim, hidden_dim, output_dim, kernel_type='spline', num_knots=num_knots)
# trained_model.load_state_dict(torch.load('model_checkpoints/model_epoch_2000.pth'))

# Evaluate the model
evaluate_model(trained_model, X_test, y_test, test_output_sizes, device=device)
# Out:
# Shape mismatch: expected 243, got 2700
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 81
#      74 y_test = torch.FloatTensor(test_output_rgb_flat)
#      76 # # Load the trained model
#      77 # trained_model = KAN(input_dim, hidden_dim, output_dim, kernel_type='spline', num_knots=num_knots)
#      78 # trained_model.load_state_dict(torch.load('model_checkpoints/model_epoch_2000.pth'))
#      79
#      80 # Evaluate the model
# ---> 81 evaluate_model(trained_model, X_test, y_test, test_output_sizes, device=device)
#
# Cell In[28], line 45, in evaluate_model(model, X_test, y_test, test_output_sizes, device)
#      42 with torch.no_grad():
#      43     outputs = model(X_test)
# ---> 45 reshaped_predictions = reshape_predictions(outputs.cpu().numpy(), test_output_sizes)
#      46 reshaped_ground_truth = reshape_predictions(y_test.cpu().numpy(), test_output_sizes)
#      48 accuracy = calculate_accuracy(reshaped_predictions, reshaped_ground_truth)
#
# Cell In[28], line 23, in reshape_predictions(predictions, sizes)
#      21     if expected_size != actual_size:
#      22         print(f"Shape mismatch: expected {expected_size}, got {actual_size}")
# ---> 23     reshaped_prediction = predictions[i][:num_features].reshape(height, width, 3)
#      24     reshaped_predictions.append(reshaped_prediction)
#      25 return reshaped_predictions
#
# ValueError: cannot reshape array of size 2700 into shape (9,9,3)

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# Function to flatten RGB arrays with size information
def flatten_rgb_arrays_with_sizes(rgb_arrays, sizes):
    flattened_arrays = []
    for rgb_array, size in zip(rgb_arrays, sizes):
        flattened_array = rgb_array.flatten()
        flattened_arrays.append(np.concatenate((flattened_array, np.array(size))))
    return np.array(flattened_arrays)

# Function to reshape predictions back to 2D
def reshape_predictions(predictions, sizes):
    reshaped_predictions = []
    num_features = predictions.shape[1] - 2  # excluding size information
    for i, size in enumerate(sizes):
        height, width = size
        expected_size = height * width * 3
        actual_size = predictions[i][:num_features].shape[0]
        if expected_size != actual_size:
            print(f"Shape mismatch: expected {expected_size}, got {actual_size}")
            print(f"Prediction shape: {predictions[i].shape}, Num features: {num_features}, Size: {size}")
            continue
        reshaped_prediction = predictions[i][:num_features].reshape(height, width, 3)
        reshaped_predictions.append(reshaped_prediction)
    return reshaped_predictions

# Function to calculate accuracy
def calculate_accuracy(predictions, ground_truth):
    correct = 0
    for pred, gt in zip(predictions, ground_truth):
        if np.array_equal(pred, gt):
            correct += 1
    accuracy = correct / len(ground_truth)
    return accuracy

# Function to load and evaluate the model
def evaluate_model(model, X_test, y_test, test_output_sizes, device='cpu'):
    model.to(device)
    X_test = X_test.to(device)
    y_test = y_test.to(device)

    with torch.no_grad():
        outputs = model(X_test)

    reshaped_predictions = reshape_predictions(outputs.cpu().numpy(), test_output_sizes)
    reshaped_ground_truth = reshape_predictions(y_test.cpu().numpy(), test_output_sizes)

    accuracy = calculate_accuracy(reshaped_predictions, reshaped_ground_truth)
    print(f'Accuracy: {accuracy:.4f}')

    # Plot the first few predictions and ground truth for comparison
    for i in range(min(5, len(reshaped_predictions))):
        fig, axs = plt.subplots(1, 2, figsize=(10, 5))
        axs[0].imshow(reshaped_predictions[i])
        axs[0].set_title('Prediction')
        axs[1].imshow(reshaped_ground_truth[i])
        axs[1].set_title('Ground Truth')
        plt.show()

    return accuracy

# Load the dataset and use train set for evaluation
dataset = load_dataset_with_sizes('processed_dataset_with_sizes.pkl')
test_input_rgb = dataset['train_input_rgb']
test_output_rgb = dataset['train_output_rgb']
test_input_sizes = dataset['train_input_sizes']
test_output_sizes = dataset['train_output_sizes']

# Debugging: Print input sizes and output sizes
print(f"test_input_sizes: {test_input_sizes[:5]}")
print(f"test_output_sizes: {test_output_sizes[:5]}")

test_input_rgb_flat = flatten_rgb_arrays_with_sizes(test_input_rgb, test_input_sizes)
test_output_rgb_flat = flatten_rgb_arrays_with_sizes(test_output_rgb, test_output_sizes)

# Debugging: Print shapes of the flattened arrays
print(f"test_input_rgb_flat shape: {test_input_rgb_flat.shape}")
print(f"test_output_rgb_flat shape: {test_output_rgb_flat.shape}")

X_test = torch.FloatTensor(test_input_rgb_flat)
y_test = torch.FloatTensor(test_output_rgb_flat)

# Load the trained model
input_dim = X_test.shape[1]
hidden_dim = 2 * input_dim + y_test.shape[1]
output_dim = y_test.shape[1]
num_knots = 10
learning_rate = 0.01

# trained_model = KAN(input_dim, hidden_dim, output_dim, kernel_type='spline', num_knots=num_knots)
# trained_model.load_state_dict(torch.load('model_checkpoints/model_epoch_2000.pth'))

# Evaluate the model
evaluate_model(trained_model, X_test, y_test, test_output_sizes, device=device)
# Out:
# test_input_sizes: [(3, 3), (3, 3), (3, 3), (3, 3), (3, 3)]
# test_output_sizes: [(9, 9), (9, 9), (9, 9), (9, 9), (9, 9)]
# test_input_rgb_flat shape: (1302, 2702)
# test_output_rgb_flat shape: (1302, 2702)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 108, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 6)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 1200, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (20, 20)
# Shape mismatch: expected 81, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 3)
# Shape mismatch: expected 81, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 3)
# Shape mismatch: expected 81, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 3)
# Shape mismatch: expected 378, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 9)
# Shape mismatch: expected 216, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (8, 9)
# Shape mismatch: expected 1323, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (21, 21)
# Shape mismatch: expected 1323, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (21, 21)
# Shape mismatch: expected 1323, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (21, 21)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 147, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 7)
# Shape mismatch: expected 147, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 7)
# Shape mismatch: expected 147, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 7)
# Shape mismatch: expected 378, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 9)
# Shape mismatch: expected 270, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 10)
# Shape mismatch: expected 330, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 10)
# Shape mismatch: expected 1200, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (20, 20)
# Shape mismatch: expected 1587, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (23, 23)
# Shape mismatch: expected 1587, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (23, 23)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 363, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 11)
# Shape mismatch: expected 363, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 11)
# Shape mismatch: expected 363, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 11)
# Shape mismatch: expected 363, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 11)
# Shape mismatch: expected 432, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 12)
# Shape mismatch: expected 432, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 12)
# Shape mismatch: expected 750, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 25)
# Shape mismatch: expected 483, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 23)
# Shape mismatch: expected 594, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (22, 9)
# Shape mismatch: expected 576, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (24, 8)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 189, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 9)
# Shape mismatch: expected 162, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 6)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 1323, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (21, 21)
# Shape mismatch: expected 1323, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (21, 21)
# Shape mismatch: expected 1323, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (21, 21)
# Shape mismatch: expected 756, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 18)
# Shape mismatch: expected 630, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 15)
# Shape mismatch: expected 672, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (16, 14)
# Shape mismatch: expected 96, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 8)
# Shape mismatch: expected 144, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 8)
# Shape mismatch: expected 180, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 6)
# Shape mismatch: expected 192, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (8, 8)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 24, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (2, 4)
# Shape mismatch: expected 18, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 2)
# Shape mismatch: expected 90, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 5)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 297, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 11)
# Shape mismatch: expected 240, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (8, 10)
# Shape mismatch: expected 216, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (8, 9)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 240, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 8)
# Shape mismatch: expected 330, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 11)
# Shape mismatch: expected 1026, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (18, 19)
# Shape mismatch: expected 630, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 14)
# Shape mismatch: expected 720, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 16)
# Shape mismatch: expected 45, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 3)
# Shape mismatch: expected 45, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 3)
# Shape mismatch: expected 45, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 3)
# Shape mismatch: expected 45, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 3)
# Shape mismatch: expected 45, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 3)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 144, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 8)
# Shape mismatch: expected 45, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 3)
# Shape mismatch: expected 240, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (8, 10)
# Shape mismatch: expected 150, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 150, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 10)
# Shape mismatch: expected 48, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 4)
# Shape mismatch: expected 45, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 3)
# Shape mismatch: expected 45, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 5)
# Shape mismatch: expected 48, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 4)
# Shape mismatch: expected 108, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 6)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 867, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (17, 17)
# Shape mismatch: expected 867, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (17, 17)
# Shape mismatch: expected 867, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (17, 17)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 45, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 15, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 5)
# Shape mismatch: expected 15, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 5)
# Shape mismatch: expected 15, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 5)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 63, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 7)
# Shape mismatch: expected 81, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 9)
# Shape mismatch: expected 81, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 9)
# Shape mismatch: expected 72, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 8)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 18, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (2, 3)
# Shape mismatch: expected 18, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 2)
# Shape mismatch: expected 36, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 4)
# Shape mismatch: expected 12, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (2, 2)
# Shape mismatch: expected 273, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 13)
# Shape mismatch: expected 330, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 11)
# Shape mismatch: expected 396, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 11)
# Shape mismatch: expected 162, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 6)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 90, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 6)
# Shape mismatch: expected 126, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 6)
# Shape mismatch: expected 396, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 11)
# Shape mismatch: expected 450, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 15)
# Shape mismatch: expected 432, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 12)
# Shape mismatch: expected 540, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 12)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 1026, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (18, 19)
# Shape mismatch: expected 504, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 14)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 54, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 6)
# Shape mismatch: expected 54, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 6)
# Shape mismatch: expected 54, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 6)
# Shape mismatch: expected 108, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 6)
# Shape mismatch: expected 192, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (8, 8)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 507, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 13)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 363, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 11)
# Shape mismatch: expected 363, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 11)
# Shape mismatch: expected 363, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 11)
# Shape mismatch: expected 165, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 11)
# Shape mismatch: expected 165, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 11)
# Shape mismatch: expected 972, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (18, 18)
# Shape mismatch: expected 972, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (18, 18)
# Shape mismatch: expected 972, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (18, 18)
# Shape mismatch: expected 972, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (18, 18)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 432, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 12)
# Shape mismatch: expected 432, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 12)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 324, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 12)
# Shape mismatch: expected 360, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 12)
# Shape mismatch: expected 504, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 12)
# Shape mismatch: expected 756, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 18)
# Shape mismatch: expected 12, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (2, 2)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 1200, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (20, 20)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 48, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 4)
# Shape mismatch: expected 12, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (2, 2)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 867, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (17, 17)
# Shape mismatch: expected 867, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (17, 17)
# Shape mismatch: expected 867, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (17, 17)
# Shape mismatch: expected 768, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (16, 16)
# Shape mismatch: expected 768, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (16, 16)
# Shape mismatch: expected 90, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 5)
# Shape mismatch: expected 90, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 5)
# Shape mismatch: expected 90, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 5)
# Shape mismatch: expected 90, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 5)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 351, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 13)
# Shape mismatch: expected 351, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 13)
# Shape mismatch: expected 351, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 13)
# Shape mismatch: expected 507, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 13)
# Shape mismatch: expected 507, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 13)
# Shape mismatch: expected 507, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 13)
# Shape mismatch: expected 918, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (17, 18)
# Shape mismatch: expected 720, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 16)
# Shape mismatch: expected 630, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 14)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 1728, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (24, 24)
# Shape mismatch: expected 2187, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (27, 27)
# Shape mismatch: expected 2187, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (27, 27)
# Shape mismatch: expected 147, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 7)
# Shape mismatch: expected 147, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 7)
# Shape mismatch: expected 180, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 10)
# Shape mismatch: expected 126, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 7)
# Shape mismatch: expected 144, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 8)
# Shape mismatch: expected 144, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 8)
# Shape mismatch: expected 144, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 8)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 147, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 7)
# Shape mismatch: expected 720, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (8, 30)
# Shape mismatch: expected 480, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (8, 20)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 45, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 5)
# Shape mismatch: expected 48, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 4)
# Shape mismatch: expected 96, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 8)
# Shape mismatch: expected 507, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 13)
# Shape mismatch: expected 507, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 13)
# Shape mismatch: expected 507, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 13)
# Shape mismatch: expected 507, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 13)
# Shape mismatch: expected 270, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 30)
# Shape mismatch: expected 240, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 20)
# Shape mismatch: expected 120, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (2, 20)
# Shape mismatch: expected 240, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 20)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 105, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 7)
# Shape mismatch: expected 90, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 5)
# Shape mismatch: expected 1800, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (30, 20)
# Shape mismatch: expected 600, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (20, 10)
# Shape mismatch: expected 588, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 14)
# Shape mismatch: expected 588, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 14)
# Shape mismatch: expected 588, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 14)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 147, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 7)
# Shape mismatch: expected 147, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 7)
# Shape mismatch: expected 363, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 11)
# Shape mismatch: expected 528, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (16, 11)
# Shape mismatch: expected 648, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 18)
# Shape mismatch: expected 627, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 19)
# Shape mismatch: expected 459, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (17, 9)
# Shape mismatch: expected 864, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (18, 16)
# Shape mismatch: expected 168, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (8, 7)
# Shape mismatch: expected 396, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 12)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 12, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (2, 2)
# Shape mismatch: expected 12, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (2, 2)
# Shape mismatch: expected 12, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (2, 2)
# Shape mismatch: expected 504, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 12)
# Shape mismatch: expected 504, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 12)
# Shape mismatch: expected 504, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 12)
# Shape mismatch: expected 432, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 12)
# Shape mismatch: expected 432, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 12)
# Shape mismatch: expected 432, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 12)
# Shape mismatch: expected 432, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 12)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 351, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 13)
# Shape mismatch: expected 429, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 13)
# Shape mismatch: expected 507, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 13)
# Shape mismatch: expected 48, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 4)
# Shape mismatch: expected 108, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 6)
# Shape mismatch: expected 108, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 6)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 1200, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (20, 20)
# Shape mismatch: expected 1200, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (20, 20)
# Shape mismatch: expected 1200, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (20, 20)
# Shape mismatch: expected 1200, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (20, 20)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 192, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (8, 8)
# Shape mismatch: expected 108, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 6)
# Shape mismatch: expected 2523, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (29, 29)
# Shape mismatch: expected 2523, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (29, 29)
# Shape mismatch: expected 2523, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (29, 29)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 1800, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (20, 30)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 504, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 14)
# Shape mismatch: expected 90, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 3)
# Shape mismatch: expected 150, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 5)
# Shape mismatch: expected 48, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 4)
# Shape mismatch: expected 60, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 5)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 9, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 3)
# Shape mismatch: expected 9, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 1)
# Shape mismatch: expected 12, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 1)
# Shape mismatch: expected 72, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 4)
# Shape mismatch: expected 72, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 4)
# Shape mismatch: expected 72, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 4)
# Shape mismatch: expected 72, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 4)
# Shape mismatch: expected 588, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 14)
# Shape mismatch: expected 588, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 14)
# Shape mismatch: expected 432, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 12)
# Shape mismatch: expected 1320, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (20, 22)
# Shape mismatch: expected 1200, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (20, 20)
# Shape mismatch: expected 1026, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (18, 19)
# Shape mismatch: expected 396, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 12)
# Shape mismatch: expected 432, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 12)
# Shape mismatch: expected 432, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 12)
# Shape mismatch: expected 432, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 12)
# Shape mismatch: expected 585, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 15)
# Shape mismatch: expected 396, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 11)
# Shape mismatch: expected 468, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 13)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 273, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 13)
# Shape mismatch: expected 273, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 7)
# Shape mismatch: expected 147, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 7)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 192, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (8, 8)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 105, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 7)
# Shape mismatch: expected 99, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 11)
# Shape mismatch: expected 99, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 11)
# Shape mismatch: expected 99, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 11)
# Shape mismatch: expected 231, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 11)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 192, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 16)
# Shape mismatch: expected 255, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (17, 5)
# Shape mismatch: expected 255, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (17, 5)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 168, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 8)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 198, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 11)
# Shape mismatch: expected 576, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (16, 12)
# Shape mismatch: expected 864, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (16, 18)
# Shape mismatch: expected 918, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (17, 18)
# Shape mismatch: expected 810, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 18)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 1587, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (23, 23)
# Shape mismatch: expected 1587, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (23, 23)
# Shape mismatch: expected 1587, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (23, 23)
# Shape mismatch: expected 540, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 12)
# Shape mismatch: expected 192, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (8, 8)
# Shape mismatch: expected 162, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 9)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 147, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 7)
# Shape mismatch: expected 108, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 6)
# Shape mismatch: expected 108, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 6)
# Shape mismatch: expected 108, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 6)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 48, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 4)
# Shape mismatch: expected 48, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 4)
# Shape mismatch: expected 48, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 4)
# Shape mismatch: expected 48, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 4)
# Shape mismatch: expected 702, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (18, 13)
# Shape mismatch: expected 429, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 13)
# Shape mismatch: expected 528, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 16)
# Shape mismatch: expected 720, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 16)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 72, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 6)
# Shape mismatch: expected 48, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 4)
# Shape mismatch: expected 90, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 6)
# Shape mismatch: expected 456, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (19, 8)
# Shape mismatch: expected 600, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (20, 10)
# Shape mismatch: expected 600, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (20, 10)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 48, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 4)
# Shape mismatch: expected 147, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 7)
# Shape mismatch: expected 108, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 6)
# Shape mismatch: expected 48, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 4)
# Shape mismatch: expected 192, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (8, 8)
# Shape mismatch: expected 108, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 6)
# Shape mismatch: expected 108, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 6)
# Shape mismatch: expected 108, got 2700
# ...
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 45, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 3)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 147, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 7)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 363, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 11)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 60, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 2)
# Shape mismatch: expected 90, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 3)
# Shape mismatch: expected 120, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 4)
# Shape mismatch: expected 396, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 11)
# Shape mismatch: expected 630, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 14)
# Shape mismatch: expected 663, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 17)
# Shape mismatch: expected 546, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 14)
# Shape mismatch: expected 630, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 14)
# Shape mismatch: expected 120, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 4)
# Shape mismatch: expected 120, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 4)
# Shape mismatch: expected 120, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 4)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 1197, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (19, 21)
# Shape mismatch: expected 330, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 11)
# Shape mismatch: expected 504, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 12)
# Shape mismatch: expected 60, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 4)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 72, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 4)
# Shape mismatch: expected 765, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 17)
# Shape mismatch: expected 330, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (11, 10)
# Shape mismatch: expected 240, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 8)
# Shape mismatch: expected 684, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 19)
# Shape mismatch: expected 624, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 16)
# Shape mismatch: expected 765, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 17)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 504, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 14)
# Shape mismatch: expected 585, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 15)
# Shape mismatch: expected 576, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 16)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 165, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 11)
# Shape mismatch: expected 165, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 11)
# Shape mismatch: expected 165, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 11)
# Shape mismatch: expected 36, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (2, 6)
# Shape mismatch: expected 36, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (2, 6)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 147, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 7)
# Shape mismatch: expected 459, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 17)
# Shape mismatch: expected 663, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 17)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 147, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 7)
# Shape mismatch: expected 108, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 6)
# Shape mismatch: expected 192, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (8, 8)
# Shape mismatch: expected 243, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (9, 9)
# Shape mismatch: expected 432, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 12)
# Shape mismatch: expected 507, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 13)
# Shape mismatch: expected 702, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (13, 18)
# Shape mismatch: expected 612, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (17, 12)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 612, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (17, 12)
# Shape mismatch: expected 420, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 10)
# Shape mismatch: expected 432, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 12)
# Shape mismatch: expected 741, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (19, 13)
# Shape mismatch: expected 765, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 17)
# Shape mismatch: expected 864, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (16, 18)
# Shape mismatch: expected 144, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 8)
# Shape mismatch: expected 108, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 6)
# Shape mismatch: expected 144, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (8, 6)
# Shape mismatch: expected 120, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 4)
# Shape mismatch: expected 120, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 4)
# Shape mismatch: expected 36, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 3)
# Shape mismatch: expected 36, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 3)
# Shape mismatch: expected 36, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 3)
# Shape mismatch: expected 36, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 3)
# Shape mismatch: expected 36, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 3)
# Shape mismatch: expected 588, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (14, 14)
# Shape mismatch: expected 714, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (17, 14)
# Shape mismatch: expected 816, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (17, 16)
# Shape mismatch: expected 816, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (17, 16)
# Shape mismatch: expected 108, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 6)
# Shape mismatch: expected 432, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (12, 12)
# Shape mismatch: expected 48, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (4, 4)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 9, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 1)
# Shape mismatch: expected 9, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 1)
# Shape mismatch: expected 9, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 1)
# Shape mismatch: expected 9, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 1)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 9, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 1)
# Shape mismatch: expected 9, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 1)
# Shape mismatch: expected 9, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 1)
# Shape mismatch: expected 12, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (2, 2)
# Shape mismatch: expected 3, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (1, 1)
# Shape mismatch: expected 12, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (2, 2)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 147, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 7)
# Shape mismatch: expected 126, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (6, 7)
# Shape mismatch: expected 147, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (7, 7)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 300, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (10, 10)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 675, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (15, 15)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 27, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (3, 3)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Shape mismatch: expected 75, got 2700
# Prediction shape: (2702,), Num features: 2700, Size: (5, 5)
# Accuracy: 0.0000
# 0.0

# %%
def resume_training(model, optimizer, X_train, y_train, start_epoch, end_epoch=2000, learning_rate=0.01, save_step=100, save_path="model_checkpoints", device='cpu'):
    criterion = nn.MSELoss()
    loss_list = []

    model.to(device)
    X_train = X_train.to(device)
    y_train = y_train.to(device)

    for epoch in range(start_epoch, end_epoch):
        model.train()
        optimizer.zero_grad()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()

        loss_list.append(loss.item())
        if (epoch + 1) % save_step == 0:
            torch.save(model.state_dict(), os.path.join(save_path, f"model_epoch_{epoch + 1}.pth"))
            torch.save(optimizer.state_dict(), os.path.join(save_path, f"optimizer_epoch_{epoch + 1}.pth"))
            print(f"Epoch [{epoch + 1}/{end_epoch}], Loss: {loss.item():.4f}, Model saved.")

    print(f"Training complete! Epoch [{end_epoch}], Loss: {loss.item():.4f}")
    return model, loss_list

# Resuming training
last_epoch = 2000
trained_model = KAN(input_dim, hidden_dim, output_dim, kernel_type='spline', num_knots=num_knots)
trained_model.load_state_dict(torch.load(f'{save_path}/model_epoch_{last_epoch}.pth'))

optimizer = optim.Adam(trained_model.parameters(), lr=learning_rate)
optimizer.load_state_dict(torch.load(f'{save_path}/model_epoch_{last_epoch}.pth'))

start_epoch = last_epoch+1
end_epoch = start_epoch+2000  # Continue training for 2000 more epochs

trained_model, loss_list = resume_training(trained_model, optimizer, X_train, y_train, start_epoch, end_epoch, learning_rate, save_step, save_path, device=device)

# %%
import torch
import numpy as np

# Function to reshape predictions back to 2D
def reshape_predictions(predictions, sizes):
    reshaped_predictions = []
    num_features = predictions.shape[1] - 2  # excluding size information
    for i, size in enumerate(sizes):
        height, width = size
        reshaped_prediction = predictions[i][:num_features].reshape(height, width, 3)
        reshaped_predictions.append(reshaped_prediction)
    return reshaped_predictions

# Function to calculate accuracy
def calculate_accuracy(predictions, ground_truth):
    correct = 0
    for pred, gt in zip(predictions, ground_truth):
        if np.array_equal(pred, gt):
            correct += 1
    accuracy = correct / len(ground_truth)
    return accuracy

# Function to load and evaluate the model
def evaluate_model(model, X_test, y_test, test_output_sizes, device='cpu'):
    model.to(device)
    X_test = X_test.to(device)
    y_test = y_test.to(device)

    with torch.no_grad():
        outputs = model(X_test)

    reshaped_predictions = reshape_predictions(outputs.cpu().numpy(), test_output_sizes)
    reshaped_ground_truth = reshape_predictions(y_test.cpu().numpy(), test_output_sizes)

    accuracy = calculate_accuracy(reshaped_predictions, reshaped_ground_truth)
    print(f'Accuracy: {accuracy:.4f}')
    return accuracy

# Example usage for evaluation
dataset = load_dataset_with_sizes('processed_dataset_with_sizes.pkl')
test_input_rgb = dataset['test_input_rgb']
test_output_rgb = dataset['test_output_rgb']
test_input_sizes = dataset['test_input_sizes']
test_output_sizes = dataset['test_output_sizes']

test_input_rgb_flat = flatten_rgb_arrays_with_sizes(test_input_rgb, test_input_sizes)
test_output_rgb_flat = flatten_rgb_arrays_with_sizes(test_output_rgb, test_output_sizes)

X_test = torch.FloatTensor(test_input_rgb_flat)
y_test = torch.FloatTensor(test_output_rgb_flat)

# Load the trained model
trained_model = KAN(input_dim, hidden_dim, output_dim, kernel_type='spline', num_knots=num_knots)
trained_model.load_state_dict(torch.load('model_checkpoints/model_epoch_2000.pth'))

# Evaluate the model
evaluate_model(trained_model, X_test, y_test, test_output_sizes, device=device)

# %%
# Save the entire model
torch.save(trained_model, 'kan_model.pth')
print('Model saved to kan_model.pth')
# Out:
# Model saved to kan_model.pth

# %%
# Load the entire model
loaded_model = torch.load('kan_model.pth')
loaded_model.eval()  # Set the model to evaluation mode
print('Model loaded from kan_model.pth')
# Out:
# Model loaded from kan_model.pth
